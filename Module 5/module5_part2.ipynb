# %% [markdown]
# # While Loop in Python
#
# ## Introduction
# A `while` loop in Python is used to repeatedly execute a block of code as long as a given condition is `True`.
#
# ## Syntax
# ```python
# while condition:
#     # Code to execute
# ```
#
# ## Example 1: Basic While Loop
# ```python
# count = 1
# while count <= 5:
#     print("Count:", count)
#     count += 1
# ```
#
# ## Example 2: Using `break`
# ```python
# x = 0
# while x < 10:
#     if x == 5:
#         break  # Exits the loop when x is 5
#     print(x)
#     x += 1
# ```
#
# ## Example 3: Using `continue`
# ```python
# y = 0
# while y < 5:
#     y += 1
#     if y == 3:
#         continue  # Skips the rest of the loop when y is 3
#     print(y)
# ```
#
# ## Example 4: Infinite Loop
# ```python
# while True:
#     print("This will run forever! Use Ctrl+C to stop.")
# ```
#
# ## Example 5: Loop with Else
# ```python
# i = 1
# while i <= 3:
#     print(i)
#     i += 1
# else:
#     print("Loop finished!")
# ```
#
# ## Conclusion
# The `while` loop is useful when the number of iterations is not known beforehand. It continues execution until a specified condition becomes `False`.

# %% [markdown]
# # While Loop Exercises in Python
#
# ## Exercise 1: Print Numbers from 1 to 10
# **Task:** Write a Python program using a `while` loop to print numbers from 1 to 10.
# ```python
# num = 1
# while num <= 10:
#     print(num)
#     num += 1
# ```
#
# ## Exercise 2: Sum of First N Natural Numbers
# **Task:** Write a program to calculate the sum of the first N natural numbers using a `while` loop.
# ```python
# n = int(input("Enter a number: "))
# sum_n = 0
# i = 1
# while i <= n:
#     sum_n += i
#     i += 1
# print("Sum:", sum_n)
# ```
#
# ## Exercise 3: Reverse a Number
# **Task:** Write a program that reverses an integer using a `while` loop.
# ```python
# num = int(input("Enter a number: "))
# reverse = 0
# while num > 0:
#     digit = num % 10
#     reverse = (reverse * 10) + digit
#     num //= 10
# print("Reversed Number:", reverse)
# ```
#
# ## Exercise 4: Print Even Numbers from 1 to 20
# **Task:** Use a `while` loop to print all even numbers from 1 to 20.
# ```python
# num = 2
# while num <= 20:
#     print(num)
#     num += 2
# ```
#
# ## Exercise 5: Multiplication Table
# **Task:** Write a program to print the multiplication table of a given number using a `while` loop.
# ```python
# num = int(input("Enter a number: "))
# i = 1
# while i <= 10:
#     print(f"{num} x {i} = {num * i}")
#     i += 1
# ```
#
# ## Exercise 6: Guessing Game
# **Task:** Write a guessing game where the user has to guess a predefined number.
# ```python
# secret_number = 7
# guess = -1
# while guess != secret_number:
#     guess = int(input("Guess the number: "))
#     if guess < secret_number:
#         print("Too low!")
#     elif guess > secret_number:
#         print("Too high!")
# print("Congratulations! You guessed it right.")
# ```
#
# ## Conclusion
# These exercises will help you understand the `while` loop in Python and how it can be used for different tasks. Try modifying them to explore more possibilities!
